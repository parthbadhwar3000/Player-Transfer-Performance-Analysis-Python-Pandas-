# %%
# !pip install pandas
# !pip install numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
appr=pd.read_csv('appearances.csv')
appr.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim            CLQ             0          0
# 1  2012-07-05    Ruslan Abyshov            ELQ             0          0
# 2  2012-07-05       Sander Puri            ELQ             0          0
# 3  2012-07-05   Vegar Hedenstad            ELQ             0          0
# 4  2012-07-05  Markus Henriksen            ELQ             0          0
#
#    goals  assists  minutes_played
# ...

# %%
appr.dtypes
# Out:
# appearance_id             object
# game_id                    int64
# player_id                  int64
# player_club_id             int64
# player_current_club_id     int64
# date                      object
# player_name               object
# competition_id            object
# yellow_cards               int64
# red_cards                  int64
# goals                      int64
# assists                    int64
# minutes_played             int64
# dtype: object

# %%
appr.isnull().any()
# Out:
# appearance_id             False
# game_id                   False
# player_id                 False
# player_club_id            False
# player_current_club_id    False
# date                      False
# player_name                True
# competition_id            False
# yellow_cards              False
# red_cards                 False
# goals                     False
# assists                   False
# minutes_played            False
# dtype: bool

# %%
appr.isnull().sum()
# Out:
# appearance_id             0
# game_id                   0
# player_id                 0
# player_club_id            0
# player_current_club_id    0
# date                      0
# player_name               6
# competition_id            0
# yellow_cards              0
# red_cards                 0
# goals                     0
# assists                   0
# minutes_played            0
# dtype: int64

# %%
appr[appr['player_name'].isnull()]
# Out:
#          appearance_id  game_id  player_id  player_club_id  \
# 799042  3084062_380365  3084062     380365           16486
# 799117  3084059_411294  3084059     411294            3302
# 799150  3084057_255495  3084057     255495           11596
# 799165  3102749_380365  3102749     380365           16486
# 816192  3106648_255495  3106648     255495           11596
# 840806  3118604_411294  3118604     411294            3302
#
#         player_current_club_id        date player_name competition_id  \
# 799042                      -1  2018-09-05         NaN            CDR
# 799117                      -1  2018-09-11         NaN            CDR
# 799150                      -1  2018-09-12         NaN            CDR
# 799165                      -1  2018-09-12         NaN            CDR
# 816192                      -1  2018-10-17         NaN            CDR
# 840806                      -1  2018-12-05         NaN            CDR
#
# ...

# %%
game=pd.read_csv('club_games.csv')
game.head(10)
# Out:
#    game_id  club_id  own_goals  own_position      own_manager_name  \
# 0  2320450   1468.0        0.0           NaN     Holger Bachthaler
# 1  2320454    222.0        0.0           NaN           Volkan Uluc
# 2  2320460      1.0        3.0           NaN       Jürgen Luginger
# 3  2320472   2036.0        4.0           NaN         Frank Schmidt
# 4  2321027     33.0        3.0           8.0           Jens Keller
# 5  2321033     23.0        0.0          13.0  Torsten Lieberknecht
# 6  2321044     16.0        2.0           1.0          Jürgen Klopp
# 7  2321060     23.0        0.0          18.0  Torsten Lieberknecht
# 8  2321063     33.0        2.0          13.0           Jens Keller
# 9  2321072     16.0        6.0           1.0          Jürgen Klopp
#
#    opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 0         24.0             2.0                NaN             Armin Veh
# 1         79.0             2.0                NaN        Bruno Labbadia
# ...

# %%
game.dtypes
# Out:
# game_id                    int64
# club_id                  float64
# own_goals                float64
# own_position             float64
# own_manager_name          object
# opponent_id              float64
# opponent_goals           float64
# opponent_position        float64
# opponent_manager_name     object
# hosting                   object
# is_win                     int64
# dtype: object

# %%
game
# Out:
#         game_id  club_id  own_goals  own_position     own_manager_name  \
# 0       2320450   1468.0        0.0           NaN    Holger Bachthaler
# 1       2320454    222.0        0.0           NaN          Volkan Uluc
# 2       2320460      1.0        3.0           NaN      Jürgen Luginger
# 3       2320472   2036.0        4.0           NaN        Frank Schmidt
# 4       2321027     33.0        3.0           8.0          Jens Keller
# ...         ...      ...        ...           ...                  ...
# 147385  3912717     62.0        0.0           NaN  Jindrich Trpisovsky
# 147386  3912732    602.0        0.0           NaN    Vladimir Cheburin
# 147387  3912739    540.0        0.0           NaN       Vladimír Weiss
# 147388  4031421   2156.0        0.0           NaN      José Luis Oltra
# 147389  4188444   1132.0        4.0           NaN      Vincent Kompany
#
#         opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# ...

# %%
game_sorted=game.sort_values(by=["club_id","away_id"], ascending=True)
grouped=game.groupby(['club_id'])['game_id'].count()
game_sorted.head(20)
game[game['hosting']=='Away']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/rx/rh0pw2rd5j1_2rbk78s2ddrr0000gn/T/ipykernel_23521/1487597258.py in ?()
# ----> 1 game_sorted=game.sort_values(by=["club_id","away_id"], ascending=True)
#       2 grouped=game.groupby(['club_id'])['game_id'].count()
#       3 game_sorted.head(20)
#       4 game[game['hosting']=='Away']
#
# ~/Library/CloudStorage/OneDrive-Personal/data analysis projects/football stats/archive (2)/venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7168                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7169                 f" != length of by ({len(by)})"
#    7170             )
#    7171         if len(by) > 1:
# -> 7172             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7173
# ...

# %%
game.isnull().sum()
# Out:
# game_id                      0
# club_id                     18
# own_goals                   24
# own_position             44876
# own_manager_name          1658
# opponent_id                 18
# opponent_goals              24
# opponent_position        44876
# opponent_manager_name     1658
# hosting                      0
# is_win                       0
# dtype: int64

# %%
game.dtypes
# Out:
# game_id                    int64
# club_id                  float64
# own_goals                float64
# own_position             float64
# own_manager_name          object
# opponent_id              float64
# opponent_goals           float64
# opponent_position        float64
# opponent_manager_name     object
# hosting                   object
# is_win                     int64
# dtype: object

# %%
game.fillna({col:0 for col in game.select_dtypes(include=['number']).columns},inplace=True)
game.fillna('Unknown',inplace=True)
game
# Out:
#         game_id  club_id  own_goals  own_position     own_manager_name  \
# 0       2320450   1468.0        0.0           0.0    Holger Bachthaler
# 1       2320454    222.0        0.0           0.0          Volkan Uluc
# 2       2320460      1.0        3.0           0.0      Jürgen Luginger
# 3       2320472   2036.0        4.0           0.0        Frank Schmidt
# 4       2321027     33.0        3.0           8.0          Jens Keller
# ...         ...      ...        ...           ...                  ...
# 147385  3912717     62.0        0.0           0.0  Jindrich Trpisovsky
# 147386  3912732    602.0        0.0           0.0    Vladimir Cheburin
# 147387  3912739    540.0        0.0           0.0       Vladimír Weiss
# 147388  4031421   2156.0        0.0           0.0      José Luis Oltra
# 147389  4188444   1132.0        4.0           0.0      Vincent Kompany
#
#         opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# ...

# %%
clubs=pd.read_csv('clubs.csv')
clubs.head()
# Out:
#    club_id          club_code                             name  \
# 0      105    sv-darmstadt-98                  SV Darmstadt 98
# 1    11127  ural-ekaterinburg               Ural Yekaterinburg
# 2      114  besiktas-istanbul        Beşiktaş Jimnastik Kulübü
# 3       12             as-rom       Associazione Sportiva Roma
# 4      148  tottenham-hotspur  Tottenham Hotspur Football Club
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          27         25.6
# 1                     RU1                 NaN          30         26.5
# 2                     TR1                 NaN          30         26.5
# 3                     IT1                 NaN          26         26.3
# 4                     GB1                 NaN          30         25.4
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 13                   48.1                      1
# ...

# %%
clubs.dtypes
# Out:
# club_id                      int64
# club_code                   object
# name                        object
# domestic_competition_id     object
# total_market_value         float64
# squad_size                   int64
# average_age                float64
# foreigners_number            int64
# foreigners_percentage      float64
# national_team_players        int64
# stadium_name                object
# stadium_seats                int64
# net_transfer_record         object
# coach_name                 float64
# last_season                  int64
# filename                    object
# url                         object
# dtype: object

# %%
appr
# Out:
#           appearance_id  game_id  player_id  player_club_id  \
# 0         2231978_38004  2231978      38004             853
# 1         2233748_79232  2233748      79232            8841
# 2         2234413_42792  2234413      42792            6251
# 3         2234418_73333  2234418      73333            1274
# 4        2234421_122011  2234421     122011             195
# ...                 ...      ...        ...             ...
# 1696968  4547698_661145  4547698     661145             681
# 1696969   4547698_69633  4547698      69633             985
# 1696970  4547698_811779  4547698     811779             985
# 1696971  4547698_907813  4547698     907813             681
# 1696972  4547698_926952  4547698     926952             985
#
#          player_current_club_id        date         player_name  \
# 0                           235  2012-07-03    Aurélien Joachim
# 1                          2698  2012-07-05      Ruslan Abyshov
# ...

# %%
plv=pd.read_csv('player_valuations.csv')
plv.head()
# Out:
#    player_id        date  market_value_in_eur  current_club_id  \
# 0     405973  2000-01-20               150000             3057
# 1     342216  2001-07-20               100000             1241
# 2       3132  2003-12-09               400000              126
# 3       6893  2003-12-15               900000              984
# 4         10  2004-10-04              7000000              398
#
#   player_club_domestic_competition_id
# 0                                 BE1
# 1                                 SC1
# 2                                 TR1
# 3                                 GB1
# 4                                 IT1

# %%
plv.isnull().sum()
# Out:
# player_id                              0
# date                                   0
# market_value_in_eur                    0
# current_club_id                        0
# player_club_domestic_competition_id    0
# dtype: int64

# %%
players=pd.read_csv('players.csv')
players
# Out:
#        player_id     first_name       last_name                  name  \
# 0             10       Miroslav           Klose        Miroslav Klose
# 1             26          Roman    Weidenfeller    Roman Weidenfeller
# 2             65        Dimitar        Berbatov      Dimitar Berbatov
# 3             77            NaN           Lúcio                 Lúcio
# 4             80            Tom          Starke            Tom Starke
# ...          ...            ...             ...                   ...
# 32596    1369057          Yusuf            Kurt            Yusuf Kurt
# 32597    1375876            NaN  Diego Henrique        Diego Henrique
# 32598    1378362         Orseer          Achihi         Orseer Achihi
# 32599    1380311  Prince Amoako          Junior  Prince Amoako Junior
# 32600    1380876  Gabriel Jesus           David   Gabriel Jesus David
#
#        last_season  current_club_id           player_code    country_of_birth  \
# ...

# %%
transfer=pd.read_csv('transfers.csv')
transfer
# Out:
#        player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 0          16136    2026-07-01           26/27           417         123
# 1         195778    2026-06-30           25/26            79          27
# 2         569033    2026-06-30           25/26            39          27
# 3         626913    2026-06-30           25/26           398         380
# 4         887834    2026-06-30           25/26           979        1023
# ...          ...           ...             ...           ...         ...
# 79606      35207    1995-07-01           95/96         42281       11896
# 79607      22141    1994-07-01           94/95         59178       29463
# 79608      33829    1994-07-01           94/95         58405       53957
# 79609      40680    1994-07-01           94/95         47320       47318
# 79610      61989    1993-07-01           93/94         55345       55343
#
#         from_club_name     to_club_name  transfer_fee  market_value_in_eur  \
# ...

# %%
transfer_current_season=transfer.copy()
transfer_current_season=transfer[transfer['transfer_season']=='24/25']
transfer_current_season
# Out:
#        player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 23         57796    2025-07-01           24/25          2036         515
# 70         33862    2025-06-30           24/25         10484         968
# 71         39125    2025-06-30           24/25          1244         449
# 72         59047    2025-06-30           24/25        101362       53646
# 73         66100    2025-06-30           24/25         12321         131
# ...          ...           ...             ...           ...         ...
# 7345      294804    2024-06-03           24/25           515        7020
# 7346      994604    2024-06-01           24/25         68031        2440
# 7348       23553    2024-05-31           24/25          1269        4131
# 7757     1083607    2024-02-29           24/25          3364      104282
# 79026     738770    2005-02-05           24/25         43618         172
#
#        from_club_name    to_club_name  transfer_fee  market_value_in_eur  \
# ...

# %%
transfer_current_season.isnull().sum()
# Out:
# player_id                 0
# transfer_date             0
# transfer_season           0
# from_club_id              0
# to_club_id                0
# from_club_name            0
# to_club_name              0
# transfer_fee           1559
# market_value_in_eur     558
# player_name               0
# dtype: int64

# %%
transfer_current_season.fillna(0)
# Out:
#        player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 23         57796    2025-07-01           24/25          2036         515
# 70         33862    2025-06-30           24/25         10484         968
# 71         39125    2025-06-30           24/25          1244         449
# 72         59047    2025-06-30           24/25        101362       53646
# 73         66100    2025-06-30           24/25         12321         131
# ...          ...           ...             ...           ...         ...
# 7345      294804    2024-06-03           24/25           515        7020
# 7346      994604    2024-06-01           24/25         68031        2440
# 7348       23553    2024-05-31           24/25          1269        4131
# 7757     1083607    2024-02-29           24/25          3364      104282
# 79026     738770    2005-02-05           24/25         43618         172
#
#        from_club_name    to_club_name  transfer_fee  market_value_in_eur  \
# ...

# %%
transfer_current_season
# Out:
#        player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 23         57796    2025-07-01           24/25          2036         515
# 70         33862    2025-06-30           24/25         10484         968
# 71         39125    2025-06-30           24/25          1244         449
# 72         59047    2025-06-30           24/25        101362       53646
# 73         66100    2025-06-30           24/25         12321         131
# ...          ...           ...             ...           ...         ...
# 7345      294804    2024-06-03           24/25           515        7020
# 7346      994604    2024-06-01           24/25         68031        2440
# 7348       23553    2024-05-31           24/25          1269        4131
# 7757     1083607    2024-02-29           24/25          3364      104282
# 79026     738770    2005-02-05           24/25         43618         172
#
#        from_club_name    to_club_name  transfer_fee  market_value_in_eur  \
# ...

# %%
most_expensive=transfer_current_season.sort_values(by='transfer_fee', ascending=False)
most_expensive
# Out:
#        player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 2795      576024    2024-08-12           24/25           281          13
# 1499      445939    2025-01-23           24/25            24         281
# 1594      502670    2025-01-17           24/25          6195         583
# 2815      258889    2024-08-10           24/25           989         148
# 3453      923831    2024-07-18           24/25          1082         985
# ...          ...           ...             ...           ...         ...
# 6109     1295530    2024-07-01           24/25         44828       10484
# 6110     1306131    2024-07-01           24/25         51638       12963
# 6111     1309800    2024-07-01           24/25         40902        2778
# 7348       23553    2024-05-31           24/25          1269        4131
# 79026     738770    2005-02-05           24/25         43618         172
#
#        from_club_name     to_club_name  transfer_fee  market_value_in_eur  \
# ...

# %%
merge1=pd.merge(players,transfer_current_season,on="player_id",how="inner")

# %%
merge1
# Out:
#       player_id     first_name       last_name                  name  \
# 0          4391            Boy        Waterman          Boy Waterman
# 1          7825           Pepe           Reina            Pepe Reina
# 2          9500          David        Marshall        David Marshall
# 3         12359           Niki         Mäenpää          Niki Mäenpää
# 4         12359           Niki         Mäenpää          Niki Mäenpää
# ...         ...            ...             ...                   ...
# 6034    1375876            NaN  Diego Henrique        Diego Henrique
# 6035    1378362         Orseer          Achihi         Orseer Achihi
# 6036    1380311  Prince Amoako          Junior  Prince Amoako Junior
# 6037    1380876  Gabriel Jesus           David   Gabriel Jesus David
# 6038    1380876  Gabriel Jesus           David   Gabriel Jesus David
#
#       last_season  current_club_id           player_code country_of_birth  \
# ...

# %%
merge1.sort_values(by="transfer_fee", ascending=False)
# Out:
#       player_id first_name      last_name                   name  last_season  \
# 2396     445939       Omar       Marmoush          Omar Marmoush         2024
# 3234     576024     Julián        Alvarez         Julián Alvarez         2024
# 2768     502670    Khvicha  Kvaratskhelia  Khvicha Kvaratskhelia         2024
# 1143     258889    Dominic        Solanke        Dominic Solanke         2024
# 5090     923831       Leny           Yoro              Leny Yoro         2024
# ...         ...        ...            ...                    ...          ...
# 6029    1358447       Kyan          Himpe             Kyan Himpe         2024
# 6030    1358448      Fuhna   Wirsiy Nsolo     Fuhna Wirsiy Nsolo         2024
# 6031    1364960     Darryl  Nkulikiyimana   Darryl Nkulikiyimana         2024
# 6032    1367128  Abdoulaye           Yoro         Abdoulaye Yoro         2024
# 6035    1378362     Orseer         Achihi          Orseer Achihi         2024
#
# ...

# %%
merge1.dtypes
# Out:
# player_id                                 int64
# first_name                               object
# last_name                                object
# name                                     object
# last_season                               int64
# current_club_id                           int64
# player_code                              object
# country_of_birth                         object
# city_of_birth                            object
# country_of_citizenship                   object
# date_of_birth                            object
# sub_position                             object
# position                                 object
# foot                                     object
# height_in_cm                            float64
# contract_expiration_date                 object
# agent_name                               object
# image_url                                object
# url                                      object
# current_club_domestic_competition_id     object
# ...

# %%
merge1.isnull().sum()
# Out:
# player_id                                  0
# first_name                               359
# last_name                                  0
# name                                       0
# last_season                                0
# current_club_id                            0
# player_code                                0
# country_of_birth                         484
# city_of_birth                            484
# country_of_citizenship                     0
# date_of_birth                              2
# sub_position                               9
# position                                   0
# foot                                     279
# height_in_cm                             301
# contract_expiration_date                 682
# agent_name                              1901
# image_url                                  0
# url                                        0
# current_club_domestic_competition_id       0
# current_club_name                          0
# ...

# %%
merge1.fillna({col:0 for col in merge1.select_dtypes(include='number').columns})
merge1.fillna('N/A',inplace=True)
merge1
# Out:
# /var/folders/rx/rh0pw2rd5j1_2rbk78s2ddrr0000gn/T/ipykernel_23521/2791640089.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   merge1.fillna('N/A',inplace=True)
#       player_id     first_name       last_name                  name  \
# 0          4391            Boy        Waterman          Boy Waterman
# 1          7825           Pepe           Reina            Pepe Reina
# 2          9500          David        Marshall        David Marshall
# 3         12359           Niki         Mäenpää          Niki Mäenpää
# 4         12359           Niki         Mäenpää          Niki Mäenpää
# ...         ...            ...             ...                   ...
# 6034    1375876            N/A  Diego Henrique        Diego Henrique
# 6035    1378362         Orseer          Achihi         Orseer Achihi
# ...

# %%
appr
# Out:
#           appearance_id  game_id  player_id  player_club_id  current_club_id  \
# 0         2231978_38004  2231978      38004             853              235
# 1         2233748_79232  2233748      79232            8841             2698
# 2         2234413_42792  2234413      42792            6251              465
# 3         2234418_73333  2234418      73333            1274             6646
# 4        2234421_122011  2234421     122011             195             3008
# ...                 ...      ...        ...             ...              ...
# 1696968  4547698_661145  4547698     661145             681              681
# 1696969   4547698_69633  4547698      69633             985              985
# 1696970  4547698_811779  4547698     811779             985              985
# 1696971  4547698_907813  4547698     907813             681              681
# 1696972  4547698_926952  4547698     926952             985              985
#
# ...

# %%
appr.rename(columns={'player_current_club_id':'current_club_id'},inplace=True)

# %%
merge2=pd.merge(merge1,appr,on=['player_id','current_club_id'],how="inner")

# %%
merge2
# Out:
#         player_id     first_name last_name                 name  last_season  \
# 0            4391            Boy  Waterman         Boy Waterman         2023
# 1            4391            Boy  Waterman         Boy Waterman         2023
# 2            4391            Boy  Waterman         Boy Waterman         2023
# 3            4391            Boy  Waterman         Boy Waterman         2023
# 4            4391            Boy  Waterman         Boy Waterman         2023
# ...           ...            ...       ...                  ...          ...
# 451563    1310513       Aristide    Zossou      Aristide Zossou         2024
# 451564    1358447           Kyan     Himpe           Kyan Himpe         2024
# 451565    1378362         Orseer    Achihi        Orseer Achihi         2024
# 451566    1380876  Gabriel Jesus     David  Gabriel Jesus David         2024
# 451567    1380876  Gabriel Jesus     David  Gabriel Jesus David         2024
#
# ...

# %%
merge2.isnull().sum()
# Out:
# player_id                               0
# first_name                              0
# last_name                               0
# name                                    0
# last_season                             0
# current_club_id                         0
# player_code                             0
# country_of_birth                        0
# city_of_birth                           0
# country_of_citizenship                  0
# date_of_birth                           0
# sub_position                            0
# position                                0
# foot                                    0
# height_in_cm                            0
# contract_expiration_date                0
# agent_name                              0
# image_url                               0
# url                                     0
# current_club_domestic_competition_id    0
# current_club_name                       0
# market_value_in_eur_x                   0
# ...

# %%
merge2.to_csv('Stats.csv',index=False)

# %%
Stats=merge2.copy()

# %%
merge2['transfer_fee'] = pd.to_numeric(merge2['transfer_fee'], errors='coerce')

# %%
Stats=merge2.sort_values(by='transfer_fee',ascending=False)

# %%
Stats[['player_name_x','transfer_fee']]
# Out:
#           player_name_x  transfer_fee
# 350301    Omar Marmoush    75000000.0
# 397242   Julián Alvarez    75000000.0
# 397236   Julián Alvarez    75000000.0
# 397237   Julián Alvarez    75000000.0
# 397238   Julián Alvarez    75000000.0
# ...                 ...           ...
# 451561  Aristide Zossou           NaN
# 451562  Aristide Zossou           NaN
# 451563  Aristide Zossou           NaN
# 451564       Kyan Himpe           NaN
# 451565    Orseer Achihi           NaN
#
# [451568 rows x 2 columns]

# %%
Stats.head()
# Out:
#         player_id first_name last_name            name  last_season  \
# 350301     445939       Omar  Marmoush   Omar Marmoush         2024
# 397242     576024     Julián   Alvarez  Julián Alvarez         2024
# 397236     576024     Julián   Alvarez  Julián Alvarez         2024
# 397237     576024     Julián   Alvarez  Julián Alvarez         2024
# 397238     576024     Julián   Alvarez  Julián Alvarez         2024
#
#         current_club_id     player_code country_of_birth city_of_birth  \
# 350301              281   omar-marmoush            Egypt         Kairo
# 397242               13  julian-alvarez        Argentina       Calchín
# 397236               13  julian-alvarez        Argentina       Calchín
# 397237               13  julian-alvarez        Argentina       Calchín
# 397238               13  julian-alvarez        Argentina       Calchín
#
#        country_of_citizenship  ... player_club_id player_current_club_id  \
# ...

# %%
Stats.to_csv('Stats.csv',index=False)

# %%
Stats_needed_data=Stats.copy()

# %%
Stats.dtypes
# Out:
# player_id                                 int64
# first_name                               object
# last_name                                object
# name                                     object
# last_season                               int64
# current_club_id                           int64
# player_code                              object
# country_of_birth                         object
# city_of_birth                            object
# country_of_citizenship                   object
# date_of_birth                            object
# sub_position                             object
# position                                 object
# foot                                     object
# height_in_cm                             object
# contract_expiration_date                 object
# agent_name                               object
# image_url                                object
# url                                      object
# current_club_domestic_competition_id     object
# ...

# %%
Stats_needed_data=Stats[['player_id','player_name_x','current_club_name','transfer_fee','market_value_in_eur_y','competition_id','yellow_cards','red_cards','goals','assists','minutes_played']]

# %%
Stats_needed_data.rename(columns={'player_name_x':'player_name'},inplace=True)
Stats_needed_data.rename(columns={'market_value_in_eur_y':'market_value_in_eur'},inplace=True)
# Out:
# /var/folders/rx/rh0pw2rd5j1_2rbk78s2ddrr0000gn/T/ipykernel_23521/3303683770.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Stats_needed_data.rename(columns={'player_name_x':'player_name'},inplace=True)
# /var/folders/rx/rh0pw2rd5j1_2rbk78s2ddrr0000gn/T/ipykernel_23521/3303683770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Stats_needed_data.rename(columns={'market_value_in_eur_y':'market_value_in_eur'},inplace=True)

# %%
Stats_needed_data.head(20)
# Out:
#         player_id     player_name               current_club_name  \
# 350301     445939   Omar Marmoush   Manchester City Football Club
# 397242     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397236     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397237     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397238     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397239     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397240     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397241     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397243     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397251     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397244     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397245     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# 397246     576024  Julián Alvarez  Club Atlético de Madrid S.A.D.
# ...

# %%
Stats_needed_data.isnull().sum()
Stats_needed_data.fillna(0)
# Out:
#         player_id      player_name                      current_club_name  \
# 350301     445939    Omar Marmoush          Manchester City Football Club
# 397242     576024   Julián Alvarez         Club Atlético de Madrid S.A.D.
# 397236     576024   Julián Alvarez         Club Atlético de Madrid S.A.D.
# 397237     576024   Julián Alvarez         Club Atlético de Madrid S.A.D.
# 397238     576024   Julián Alvarez         Club Atlético de Madrid S.A.D.
# ...           ...              ...                                    ...
# 451561    1310513  Aristide Zossou  Association de la Jeunesse auxerroise
# 451562    1310513  Aristide Zossou  Association de la Jeunesse auxerroise
# 451563    1310513  Aristide Zossou  Association de la Jeunesse auxerroise
# 451564    1358447       Kyan Himpe       Koninklijke Voetbalclub Kortrijk
# 451565    1378362    Orseer Achihi            Royal Antwerp Football Club
#
#         transfer_fee market_value_in_eur competition_id  yellow_cards  \
# ...

# %%
Stats_needed_data.to_csv('Stats_new.csv',index=False)

# %%
grouping=Stats_needed_data.copy()

# %%
grouping=Stats_needed_data.groupby(['player_name','transfer_fee','market_value_in_eur'])[['minutes_played','goals','assists','yellow_cards','red_cards']].sum().reset_index()

# %%
grouping
# Out:
#              player_name  transfer_fee market_value_in_eur  minutes_played  \
# 0     Aaron Appindangoyé           0.0            800000.0            9601
# 1         Aaron Donnelly           0.0            400000.0            5064
# 2         Aaron Donnelly           0.0            500000.0            2532
# 3         Aaron Ramsdale    21400000.0          25000000.0           17310
# 4             Aaron Reid           0.0                 N/A             289
# ...                  ...           ...                 ...             ...
# 3493        Úmaro Embaló           0.0            700000.0            4980
# 3494          Ümit Akdağ           0.0            800000.0             970
# 3495      İbrahim Yılmaz           0.0            200000.0            1710
# 3496      İlkay Gündoğan           0.0          15000000.0           35593
# 3497      Ștefan Vlădoiu           0.0           1000000.0             332
#
#       goals  assists  yellow_cards  red_cards
# ...

# %%
sorted=grouping.sort_values(by=['transfer_fee','goals','assists','minutes_played','yellow_cards','red_cards'],ascending=[False,False,False,False,True,True])

# %%
sorted.head(20)
# Out:
#                 player_name  transfer_fee market_value_in_eur  minutes_played  \
# 1673         Julián Alvarez    75000000.0          90000000.0            8687
# 2558          Omar Marmoush    75000000.0          60000000.0            8737
# 1768  Khvicha Kvaratskhelia    70000000.0          85000000.0           12378
# 843         Dominic Solanke    64300000.0          40000000.0           13681
# 1859              Leny Yoro    62000000.0          50000000.0            4719
# 2341           Moussa Diaby    60000000.0          55000000.0           16687
# 2645             Pedro Neto    60000000.0          55000000.0            9156
# 2427          Nico González    60000000.0          18000000.0            7651
# 1633             João Neves    59920000.0          55000000.0            6892
# 169            Amadou Onana    59350000.0          50000000.0            8294
# 674               Dani Olmo    55000000.0          60000000.0           11268
# ...

# %%
sorted.to_csv('Transferdata.csv',index=False)
